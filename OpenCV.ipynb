# %% [markdown]
# <a href="https://colab.research.google.com/github/siripornbow/Lab/blob/master/OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt 
# %matplotlib inline
import cv2

# %%
print(cv2.__version__)
# Out:
# 3.4.3

# %%
from google.colab import files #

# %%
f = files.upload()
# Out:
#      <input type="file" id="files-061ea3fe-9730-45c5-abb7-3538c214c6a8" name="files[]" multiple disabled />
#      <output id="result-061ea3fe-9730-45c5-abb7-3538c214c6a8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving b.jpeg to b.jpeg

# %%
cat=cv2.imread("./b.jpeg")
cat = cv2.cvtColor(cat, cv2.COLOR_BGR2RGB)#การแปลงสี
plt.imshow(cat)

# %%
print("width: %d pixels" % (cat.shape[1]))
print("height: %d pixels" % (cat.shape[0]))
print("channels: %d" % (cat.shape[2]))
# Out:
# width: 300 pixels
# height: 168 pixels
# channels: 3

# %%
cat = cv2.imread("./b.jpeg")
(h, w) = cat.shape[:2]
plt.imshow(cat)

# %%
(b, g, r) = cat[0, 0]
print("Pixel at (0, 0) - Red: {r}, Green: {g}, Blue: {b}".format(r=r, g=g, b=b))
 

cat[0, 0] = (0, 0, 255)
(b, g, r) = cat[0, 0]
print("Pixel at (0, 0) - Red: {r}, Green: {g}, Blue: {b}".format(r=r, g=g, b=b))
# Out:
# Pixel at (0, 0) - Red: 255, Green: 0, Blue: 0
# Pixel at (0, 0) - Red: 255, Green: 0, Blue: 0
